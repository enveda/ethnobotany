# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from collections import defaultdict

from io import StringIO

from ete3 import NCBITaxa

# %%
from matplotlib.pyplot import figure
from matplotlib.patches import Circle

from Bio import Phylo
from random import randint

from PhyloCircular import polar_plot
from PhyloCircular import Externals_labels, Externals_patchs, Externals_heatmap

# %% [markdown]
# ### Load data

# %%
DATA_DIR = '../data/processed'

# %%
plant_data = pd.read_csv(f'{DATA_DIR}/plant_disease_collapsed.tsv', sep='\t')
plant_data = plant_data[plant_data['database'] != 'bern2']
plant_data.head(3)
# Out:
# /var/folders/61/bn_r735d70z03hg56wh7hsg80000gn/T/ipykernel_6825/357951436.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   plant_data = pd.read_csv(f'{DATA_DIR}/plant_disease_collapsed.tsv', sep='\t')
#              plant_curie plant_name  disease_curie database  \
# 129539  ncbitaxon:103823        NaN  mondo:0005550      etm
# 129540  ncbitaxon:103823        NaN  mondo:0005046      etm
# 129541  ncbitaxon:107365        NaN  mondo:0002081      etm
#
#                                                  evidence
# 129539  Engedasew Andarge, Abraham Shonga, Mathewos Ag...
# 129540  Engedasew Andarge, Abraham Shonga, Mathewos Ag...
# 129541  Araya, S., Abera, B., & Giday, M. (2015). Stud...

# %%
plant_disease_data = pd.read_csv(
    f'{DATA_DIR}/non_binary_database_df.tsv', sep='\t', index_col='Unnamed: 0'
)
# plant_disease_data = plant_disease_data[plant_disease_data['database'] == 'bern2']
plant_disease_data.head(3)
# Out:
#                                                 ncbitaxon:103823  \
# mondo:0005550  {'Engedasew Andarge, Abraham Shonga, Mathewos ...
# mondo:0005046  {'Engedasew Andarge, Abraham Shonga, Mathewos ...
# mondo:0002081                                                NaN
#
#                                                 ncbitaxon:107365  \
# mondo:0005550                                                NaN
# mondo:0005046  {'Araya, S., Abera, B., & Giday, M. (2015). St...
# mondo:0002081  {'Araya, S., Abera, B., & Giday, M. (2015). St...
#
#               ncbitaxon:1090597  \
# mondo:0005550               NaN
# mondo:0005046               NaN
# mondo:0002081               NaN
#
#                                                 ncbitaxon:110835  \
# mondo:0005550  {'Teklehaymanot, T., Giday, M., Medhin, G., & ...
# mondo:0005046                                                NaN
# mondo:0002081                                                NaN
#
#                                                ncbitaxon:1129974  \
# mondo:0005550  {'Araya, S., Abera, B., & Giday, M. (2015). St...
# mondo:0005046                                                NaN
# mondo:0002081                                                NaN
#
#                                                ncbitaxon:1205696  \
# mondo:0005550                                                NaN
# mondo:0005046  {'Desta, B. (1993). Ethiopian traditional herb...
# mondo:0002081                                                NaN
#
#               ncbitaxon:1220069  \
# mondo:0005550               NaN
# mondo:0005046               NaN
# mondo:0002081               NaN
#
#                                                ncbitaxon:1232590  \
# mondo:0005550  {'Megersa, M., Asfaw, Z., Kelbessa, E., Beyene...
# mondo:0005046                                                NaN
# mondo:0002081                                                NaN
#
#               ncbitaxon:123405  \
# mondo:0005550              NaN
# mondo:0005046              NaN
# mondo:0002081              NaN
#
#                                                ncbitaxon:1236437  ...  \
# mondo:0005550  {'Birhanu, Z., Endale, A., & Shewamene, Z. (20...  ...
# mondo:0005046                                                NaN  ...
# mondo:0002081                                                NaN  ...
#
#               ncbitaxon:97307 ncbitaxon:97319 ncbitaxon:977953  \
# mondo:0005550             NaN             NaN              NaN
# mondo:0005046             NaN             NaN              NaN
# mondo:0002081             NaN             NaN              NaN
#
#                 ncbitaxon:979727   ncbitaxon:984478    ncbitaxon:98504  \
# mondo:0005550  {'From KoreanTK'}  {'From KoreanTK'}                NaN
# mondo:0005046                NaN                NaN  {'From KoreanTK'}
# mondo:0002081                NaN                NaN  {'From KoreanTK'}
#
#                 ncbitaxon:992642 ncbitaxon:99520 ncbitaxon:99570  \
# mondo:0005550  {'From KoreanTK'}             NaN             NaN
# mondo:0005046  {'From KoreanTK'}             NaN             NaN
# mondo:0002081                NaN             NaN             NaN
#
#                  ncbitaxon:99809
# mondo:0005550                NaN
# mondo:0005046  {'From KoreanTK'}
# mondo:0002081  {'From KoreanTK'}
#
# [3 rows x 2338 columns]

# %%
plants = plant_disease_data.columns.tolist()

# %%
import ast

# %%
plant_disease_dict = defaultdict(int)

for index, row in tqdm(plant_disease_data.iterrows(), total=plant_disease_data.shape[0]):
    for plant_name, citations in row.items():
        if not isinstance(citations, str):
            continue
        citations = ast.literal_eval(citations)
        plant_disease_dict[f'{plant_name}_{index}'] += len(citations)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 124.76it/s]

# %%
list(plant_disease_dict.keys())
# Out:
# ['ncbitaxon:103823_mondo:0005550',
#  'ncbitaxon:110835_mondo:0005550',
#  'ncbitaxon:1129974_mondo:0005550',
#  'ncbitaxon:1232590_mondo:0005550',
#  'ncbitaxon:1236437_mondo:0005550',
#  'ncbitaxon:1242813_mondo:0005550',
#  'ncbitaxon:1298700_mondo:0005550',
#  'ncbitaxon:1300200_mondo:0005550',
#  'ncbitaxon:13465_mondo:0005550',
#  'ncbitaxon:159034_mondo:0005550',
#  'ncbitaxon:1632797_mondo:0005550',
#  'ncbitaxon:1665489_mondo:0005550',
#  'ncbitaxon:1670852_mondo:0005550',
#  'ncbitaxon:169279_mondo:0005550',
#  'ncbitaxon:183238_mondo:0005550',
#  'ncbitaxon:1874191_mondo:0005550',
#  'ncbitaxon:191453_mondo:0005550',
#  'ncbitaxon:198859_mondo:0005550',
#  'ncbitaxon:198863_mondo:0005550',
#  'ncbitaxon:2016425_mondo:0005550',
#  'ncbitaxon:2024931_mondo:0005550',
#  'ncbitaxon:204151_mondo:0005550',
#  'ncbitaxon:2152782_mondo:0005550',
#  'ncbitaxon:219240_mondo:0005550',
#  'ncbitaxon:225019_mondo:0005550',
#  'ncbitaxon:256486_mondo:0005550',
#  'ncbitaxon:2676176_mondo:0005550',
#  'ncbitaxon:2708_mondo:0005550',
#  'ncbitaxon:32198_mondo:0005550',
#  'ncbitaxon:34317_mondo:0005550',
#  'ncbitaxon:34329_mondo:0005550',
#  'ncbitaxon:3668_mondo:0005550',
#  'ncbitaxon:3670_mondo:0005550',
#  'ncbitaxon:3821_mondo:0005550',
#  'ncbitaxon:3864_mondo:0005550',
#  'ncbitaxon:3983_mondo:0005550',
#  'ncbitaxon:3992_mondo:0005550',
#  'ncbitaxon:4075_mondo:0005550',
#  'ncbitaxon:4076_mondo:0005550',
#  'ncbitaxon:4142_mondo:0005550',
#  'ncbitaxon:428233_mondo:0005550',
#  'ncbitaxon:4463_mondo:0005550',
#  'ncbitaxon:46147_mondo:0005550',
#  'ncbitaxon:483842_mondo:0005550',
#  'ncbitaxon:50455_mondo:0005550',
#  'ncbitaxon:51262_mondo:0005550',
#  'ncbitaxon:57921_mondo:0005550',
#  'ncbitaxon:59320_mondo:0005550',
#  'ncbitaxon:62753_mondo:0005550',
#  'ncbitaxon:642059_mondo:0005550',
#  'ncbitaxon:690845_mondo:0005550',
#  'ncbitaxon:703383_mondo:0005550',
#  'ncbitaxon:72333_mondo:0005550',
#  'ncbitaxon:796898_mondo:0005550',
#  'ncbitaxon:85202_mondo:0005550',
#  'ncbitaxon:87076_mondo:0005550',
#  'ncbitaxon:883493_mondo:0005550',
#  'ncbitaxon:904427_mondo:0005550',
#  'ncbitaxon:99438_mondo:0005550',
#  'ncbitaxon:100569_mondo:0005550',
#  'ncbitaxon:1008370_mondo:0005550',
#  'ncbitaxon:1008446_mondo:0005550',
#  'ncbitaxon:1009589_mondo:0005550',
#  'ncbitaxon:101473_mondo:0005550',
#  'ncbitaxon:102211_mondo:0005550',
#  'ncbitaxon:1043496_mondo:0005550',
#  'ncbitaxon:1045171_mondo:0005550',
#  'ncbitaxon:1053409_mondo:0005550',
#  'ncbitaxon:1056460_mondo:0005550',
#  'ncbitaxon:105884_mondo:0005550',
#  'ncbitaxon:1060938_mondo:0005550',
#  'ncbitaxon:106335_mondo:0005550',
#  'ncbitaxon:1068672_mondo:0005550',
#  'ncbitaxon:1071182_mondo:0005550',
#  'ncbitaxon:1071187_mondo:0005550',
#  'ncbitaxon:1071199_mondo:0005550',
#  'ncbitaxon:107240_mondo:0005550',
#  'ncbitaxon:107308_mondo:0005550',
#  'ncbitaxon:1073321_mondo:0005550',
#  'ncbitaxon:1073793_mondo:0005550',
#  'ncbitaxon:1077933_mondo:0005550',
#  'ncbitaxon:107827_mondo:0005550',
#  'ncbitaxon:108362_mondo:0005550',
#  'ncbitaxon:108377_mondo:0005550',
#  'ncbitaxon:108380_mondo:0005550',
#  'ncbitaxon:108409_mondo:0005550',
#  'ncbitaxon:108544_mondo:0005550',
#  'ncbitaxon:1087055_mondo:0005550',
#  'ncbitaxon:1090620_mondo:0005550',
#  'ncbitaxon:109066_mondo:0005550',
#  'ncbitaxon:109224_mondo:0005550',
#  'ncbitaxon:109470_mondo:0005550',
#  'ncbitaxon:110284_mondo:0005550',
#  'ncbitaxon:112591_mondo:0005550',
#  'ncbitaxon:112863_mondo:0005550',
#  'ncbitaxon:1132410_mondo:0005550',
#  'ncbitaxon:1133704_mondo:0005550',
#  'ncbitaxon:113475_mondo:0005550',
#  'ncbitaxon:114476_mondo:0005550',
#  'ncbitaxon:1149812_mondo:0005550',
#  'ncbitaxon:1150289_mondo:0005550',
#  'ncbitaxon:1150928_mondo:0005550',
#  'ncbitaxon:115624_mondo:0005550',
#  'ncbitaxon:1158923_mondo:0005550',
#  'ncbitaxon:1173311_mondo:0005550',
#  'ncbitaxon:1179215_mondo:0005550',
#  'ncbitaxon:118431_mondo:0005550',
#  'ncbitaxon:118510_mondo:0005550',
#  'ncbitaxon:118778_mondo:0005550',
#  'ncbitaxon:120149_mondo:0005550',
#  'ncbitaxon:120290_mondo:0005550',
#  'ncbitaxon:1205743_mondo:0005550',
#  'ncbitaxon:1205786_mondo:0005550',
#  'ncbitaxon:121073_mondo:0005550',
#  'ncbitaxon:1217422_mondo:0005550',
#  'ncbitaxon:122308_mondo:0005550',
#  'ncbitaxon:1224771_mondo:0005550',
#  'ncbitaxon:122832_mondo:0005550',
#  'ncbitaxon:123464_mondo:0005550',
#  'ncbitaxon:124768_mondo:0005550',
#  'ncbitaxon:124778_mondo:0005550',
#  'ncbitaxon:124781_mondo:0005550',
#  'ncbitaxon:124848_mondo:0005550',
#  'ncbitaxon:1249012_mondo:0005550',
#  'ncbitaxon:124943_mondo:0005550',
#  'ncbitaxon:125587_mondo:0005550',
#  'ncbitaxon:1260214_mondo:0005550',
#  'ncbitaxon:1260927_mondo:0005550',
#  'ncbitaxon:126430_mondo:0005550',
#  'ncbitaxon:126433_mondo:0005550',
#  'ncbitaxon:126435_mondo:0005550',
#  'ncbitaxon:126820_mondo:0005550',
#  'ncbitaxon:126910_mondo:0005550',
#  'ncbitaxon:127999_mondo:0005550',
#  'ncbitaxon:128002_mondo:0005550',
#  'ncbitaxon:128017_mondo:0005550',
#  'ncbitaxon:128608_mondo:0005550',
#  'ncbitaxon:128733_mondo:0005550',
#  'ncbitaxon:1288007_mondo:0005550',
#  'ncbitaxon:1288010_mondo:0005550',
#  'ncbitaxon:1288019_mondo:0005550',
#  'ncbitaxon:13044_mondo:0005550',
#  'ncbitaxon:13216_mondo:0005550',
#  'ncbitaxon:13217_mondo:0005550',
#  'ncbitaxon:13329_mondo:0005550',
#  'ncbitaxon:13337_mondo:0005550',
#  'ncbitaxon:133573_mondo:0005550',
#  'ncbitaxon:13393_mondo:0005550',
#  'ncbitaxon:1340885_mondo:0005550',
#  'ncbitaxon:13429_mondo:0005550',
#  'ncbitaxon:13447_mondo:0005550',
#  'ncbitaxon:13493_mondo:0005550',
#  'ncbitaxon:1357583_mondo:0005550',
#  'ncbitaxon:1357585_mondo:0005550',
#  'ncbitaxon:136122_mondo:0005550',
#  'ncbitaxon:136208_mondo:0005550',
#  'ncbitaxon:136217_mondo:0005550',
#  'ncbitaxon:136894_mondo:0005550',
#  'ncbitaxon:136915_mondo:0005550',
#  'ncbitaxon:137220_mondo:0005550',
#  'ncbitaxon:137221_mondo:0005550',
#  'ncbitaxon:137693_mondo:0005550',
#  'ncbitaxon:138017_mondo:0005550',
#  'ncbitaxon:138033_mondo:0005550',
#  'ncbitaxon:138043_mondo:0005550',
#  'ncbitaxon:13818_mondo:0005550',
#  'ncbitaxon:1382013_mondo:0005550',
#  'ncbitaxon:1383557_mondo:0005550',
#  'ncbitaxon:1384607_mondo:0005550',
#  'ncbitaxon:13894_mondo:0005550',
#  'ncbitaxon:139224_mondo:0005550',
#  'ncbitaxon:139741_mondo:0005550',
#  'ncbitaxon:139772_mondo:0005550',
#  'ncbitaxon:1401050_mondo:0005550',
#  'ncbitaxon:140311_mondo:0005550',
#  'ncbitaxon:141186_mondo:0005550',
#  'ncbitaxon:141189_mondo:0005550',
#  'ncbitaxon:141191_mondo:0005550',
#  'ncbitaxon:141317_mondo:0005550',
#  'ncbitaxon:141467_mondo:0005550',
#  'ncbitaxon:141541_mondo:0005550',
#  'ncbitaxon:141603_mondo:0005550',
#  'ncbitaxon:1425330_mondo:0005550',
#  'ncbitaxon:142738_mondo:0005550',
#  'ncbitaxon:142860_mondo:0005550',
#  'ncbitaxon:143782_mondo:0005550',
#  'ncbitaxon:144546_mondo:0005550',
#  'ncbitaxon:145675_mondo:0005550',
#  'ncbitaxon:145745_mondo:0005550',
#  'ncbitaxon:1464615_mondo:0005550',
#  'ncbitaxon:1472648_mondo:0005550',
#  'ncbitaxon:147273_mondo:0005550',
#  'ncbitaxon:1473222_mondo:0005550',
#  'ncbitaxon:1475012_mondo:0005550',
#  'ncbitaxon:147635_mondo:0005550',
#  'ncbitaxon:1476995_mondo:0005550',
#  'ncbitaxon:1486856_mondo:0005550',
#  'ncbitaxon:1489821_mondo:0005550',
#  'ncbitaxon:1489957_mondo:0005550',
#  'ncbitaxon:1489963_mondo:0005550',
#  'ncbitaxon:149669_mondo:0005550',
#  'ncbitaxon:151065_mondo:0005550',
#  'ncbitaxon:151069_mondo:0005550',
#  'ncbitaxon:151834_mondo:0005550',
#  'ncbitaxon:152286_mondo:0005550',
#  'ncbitaxon:1523243_mondo:0005550',
#  'ncbitaxon:1524234_mondo:0005550',
#  'ncbitaxon:153459_mondo:0005550',
#  'ncbitaxon:153524_mondo:0005550',
#  'ncbitaxon:153544_mondo:0005550',
#  'ncbitaxon:153583_mondo:0005550',
#  'ncbitaxon:153762_mondo:0005550',
#  'ncbitaxon:154990_mondo:0005550',
#  'ncbitaxon:155021_mondo:0005550',
#  'ncbitaxon:155022_mondo:0005550',
#  'ncbitaxon:155299_mondo:0005550',
#  'ncbitaxon:155640_mondo:0005550',
#  'ncbitaxon:157092_mondo:0005550',
#  'ncbitaxon:157652_mondo:0005550',
#  'ncbitaxon:157791_mondo:0005550',
#  'ncbitaxon:157914_mondo:0005550',
#  'ncbitaxon:158548_mondo:0005550',
#  'ncbitaxon:158927_mondo:0005550',
#  'ncbitaxon:159030_mondo:0005550',
#  'ncbitaxon:159033_mondo:0005550',
#  'ncbitaxon:159053_mondo:0005550',
#  'ncbitaxon:159059_mondo:0005550',
#  'ncbitaxon:159068_mondo:0005550',
#  'ncbitaxon:1592062_mondo:0005550',
#  'ncbitaxon:1603834_mondo:0005550',
#  'ncbitaxon:1612632_mondo:0005550',
#  'ncbitaxon:161756_mondo:0005550',
#  'ncbitaxon:161934_mondo:0005550',
#  'ncbitaxon:162022_mondo:0005550',
#  'ncbitaxon:162823_mondo:0005550',
#  'ncbitaxon:162876_mondo:0005550',
#  'ncbitaxon:163081_mondo:0005550',
#  'ncbitaxon:163084_mondo:0005550',
#  'ncbitaxon:16481_mondo:0005550',
#  'ncbitaxon:165298_mondo:0005550',
#  'ncbitaxon:165328_mondo:0005550',
#  'ncbitaxon:165774_mondo:0005550',
#  'ncbitaxon:1672007_mondo:0005550',
#  'ncbitaxon:167337_mondo:0005550',
#  'ncbitaxon:16752_mondo:0005550',
#  'ncbitaxon:167567_mondo:0005550',
#  'ncbitaxon:167791_mondo:0005550',
#  'ncbitaxon:167917_mondo:0005550',
#  'ncbitaxon:1679267_mondo:0005550',
#  'ncbitaxon:1679368_mondo:0005550',
#  'ncbitaxon:169373_mondo:0005550',
#  'ncbitaxon:1705610_mondo:0005550',
#  'ncbitaxon:1707848_mondo:0005550',
#  'ncbitaxon:1712202_mondo:0005550',
#  'ncbitaxon:1712208_mondo:0005550',
#  'ncbitaxon:1718193_mondo:0005550',
#  'ncbitaxon:1718196_mondo:0005550',
#  'ncbitaxon:171896_mondo:0005550',
#  'ncbitaxon:172200_mondo:0005550',
#  'ncbitaxon:172267_mondo:0005550',
#  'ncbitaxon:172644_mondo:0005550',
#  'ncbitaxon:1736744_mondo:0005550',
#  'ncbitaxon:174167_mondo:0005550',
#  'ncbitaxon:174187_mondo:0005550',
#  'ncbitaxon:174190_mondo:0005550',
#  'ncbitaxon:174649_mondo:0005550',
#  'ncbitaxon:175055_mondo:0005550',
#  'ncbitaxon:175518_mondo:0005550',
#  'ncbitaxon:175694_mondo:0005550',
#  'ncbitaxon:176258_mondo:0005550',
#  'ncbitaxon:1797131_mondo:0005550',
#  'ncbitaxon:180103_mondo:0005550',
#  'ncbitaxon:180498_mondo:0005550',
#  'ncbitaxon:180536_mondo:0005550',
#  'ncbitaxon:181185_mondo:0005550',
#  'ncbitaxon:1811969_mondo:0005550',
#  'ncbitaxon:1812335_mondo:0005550',
#  'ncbitaxon:1813066_mondo:0005550',
#  'ncbitaxon:182321_mondo:0005550',
#  'ncbitaxon:182999_mondo:0005550',
#  'ncbitaxon:183063_mondo:0005550',
#  'ncbitaxon:183220_mondo:0005550',
#  'ncbitaxon:183266_mondo:0005550',
#  'ncbitaxon:183298_mondo:0005550',
#  'ncbitaxon:184783_mondo:0005550',
#  'ncbitaxon:185002_mondo:0005550',
#  'ncbitaxon:185191_mondo:0005550',
#  'ncbitaxon:185234_mondo:0005550',
#  'ncbitaxon:1892427_mondo:0005550',
#  'ncbitaxon:1892884_mondo:0005550',
#  'ncbitaxon:1898706_mondo:0005550',
#  'ncbitaxon:190802_mondo:0005550',
#  'ncbitaxon:190804_mondo:0005550',
#  'ncbitaxon:191188_mondo:0005550',
#  'ncbitaxon:191224_mondo:0005550',
#  'ncbitaxon:191881_mondo:0005550',
#  'ncbitaxon:191885_mondo:0005550',
#  'ncbitaxon:191942_mondo:0005550',
#  'ncbitaxon:193163_mondo:0005550',
#  'ncbitaxon:193519_mondo:0005550',
#  'ncbitaxon:1948899_mondo:0005550',
#  'ncbitaxon:197248_mondo:0005550',
#  'ncbitaxon:197426_mondo:0005550',
#  'ncbitaxon:197796_mondo:0005550',
#  'ncbitaxon:198777_mondo:0005550',
#  'ncbitaxon:198899_mondo:0005550',
#  'ncbitaxon:198914_mondo:0005550',
#  'ncbitaxon:19953_mondo:0005550',
#  'ncbitaxon:201017_mondo:0005550',
#  'ncbitaxon:201509_mondo:0005550',
#  'ncbitaxon:2030897_mondo:0005550',
#  'ncbitaxon:20340_mondo:0005550',
#  'ncbitaxon:204124_mondo:0005550',
#  'ncbitaxon:204129_mondo:0005550',
#  'ncbitaxon:204135_mondo:0005550',
#  'ncbitaxon:20414_mondo:0005550',
#  'ncbitaxon:204144_mondo:0005550',
#  'ncbitaxon:204149_mondo:0005550',
#  'ncbitaxon:204219_mondo:0005550',
#  'ncbitaxon:204222_mondo:0005550',
#  'ncbitaxon:204518_mondo:0005550',
#  'ncbitaxon:205937_mondo:0005550',
#  'ncbitaxon:206309_mondo:0005550',
#  'ncbitaxon:207296_mondo:0005550',
#  'ncbitaxon:2086537_mondo:0005550',
#  'ncbitaxon:208695_mondo:0005550',
#  'ncbitaxon:210060_mondo:0005550',
#  'ncbitaxon:210143_mondo:0005550',
#  'ncbitaxon:21020_mondo:0005550',
#  'ncbitaxon:210334_mondo:0005550',
#  'ncbitaxon:210340_mondo:0005550',
#  'ncbitaxon:210347_mondo:0005550',
#  'ncbitaxon:210369_mondo:0005550',
#  'ncbitaxon:210376_mondo:0005550',
#  'ncbitaxon:210380_mondo:0005550',
#  'ncbitaxon:210859_mondo:0005550',
#  'ncbitaxon:211151_mondo:0005550',
#  'ncbitaxon:211926_mondo:0005550',
#  'ncbitaxon:212256_mondo:0005550',
#  'ncbitaxon:212310_mondo:0005550',
#  'ncbitaxon:212834_mondo:0005550',
#  'ncbitaxon:212925_mondo:0005550',
#  'ncbitaxon:213785_mondo:0005550',
#  'ncbitaxon:2138340_mondo:0005550',
#  'ncbitaxon:214053_mondo:0005550',
#  'ncbitaxon:219868_mondo:0005550',
#  'ncbitaxon:221251_mondo:0005550',
#  'ncbitaxon:221762_mondo:0005550',
#  'ncbitaxon:222877_mondo:0005550',
#  'ncbitaxon:223891_mondo:0005550',
#  'ncbitaxon:22663_mondo:0005550',
#  'ncbitaxon:22666_mondo:0005550',
#  'ncbitaxon:227722_mondo:0005550',
#  'ncbitaxon:228354_mondo:0005550',
#  'ncbitaxon:228395_mondo:0005550',
#  'ncbitaxon:22978_mondo:0005550',
#  'ncbitaxon:23110_mondo:0005550',
#  'ncbitaxon:231710_mondo:0005550',
#  'ncbitaxon:233707_mondo:0005550',
#  'ncbitaxon:233715_mondo:0005550',
#  'ncbitaxon:235806_mondo:0005550',
#  'ncbitaxon:23810_mondo:0005550',
#  'ncbitaxon:2382139_mondo:0005550',
#  'ncbitaxon:240005_mondo:0005550',
#  'ncbitaxon:240045_mondo:0005550',
#  'ncbitaxon:240453_mondo:0005550',
#  'ncbitaxon:240953_mondo:0005550',
#  'ncbitaxon:241838_mondo:0005550',
#  'ncbitaxon:241841_mondo:0005550',
#  'ncbitaxon:241857_mondo:0005550',
#  'ncbitaxon:246224_mondo:0005550',
#  'ncbitaxon:246360_mondo:0005550',
#  'ncbitaxon:2486370_mondo:0005550',
#  'ncbitaxon:2491102_mondo:0005550',
#  'ncbitaxon:259381_mondo:0005550',
#  'ncbitaxon:2601245_mondo:0005550',
#  'ncbitaxon:260142_mondo:0005550',
#  'ncbitaxon:261448_mondo:0005550',
#  'ncbitaxon:262620_mondo:0005550',
#  'ncbitaxon:263974_mondo:0005550',
#  'ncbitaxon:267599_mondo:0005550',
#  'ncbitaxon:2687262_mondo:0005550',
#  'ncbitaxon:268745_mondo:0005550',
#  'ncbitaxon:2695409_mondo:0005550',
#  'ncbitaxon:269721_mondo:0005550',
#  'ncbitaxon:271192_mondo:0005550',
#  'ncbitaxon:271807_mondo:0005550',
#  'ncbitaxon:2723579_mondo:0005550',
#  'ncbitaxon:2724607_mondo:0005550',
#  'ncbitaxon:272846_mondo:0005550',
#  'ncbitaxon:273781_mondo:0005550',
#  'ncbitaxon:2739822_mondo:0005550',
#  'ncbitaxon:278077_mondo:0005550',
#  'ncbitaxon:278672_mondo:0005550',
#  'ncbitaxon:279769_mondo:0005550',
#  'ncbitaxon:282542_mondo:0005550',
#  'ncbitaxon:283133_mondo:0005550',
#  'ncbitaxon:284589_mondo:0005550',
#  'ncbitaxon:28525_mondo:0005550',
#  'ncbitaxon:28545_mondo:0005550',
#  'ncbitaxon:285590_mondo:0005550',
#  'ncbitaxon:28909_mondo:0005550',
#  'ncbitaxon:28958_mondo:0005550',
#  'ncbitaxon:28974_mondo:0005550',
#  'ncbitaxon:289741_mondo:0005550',
#  'ncbitaxon:289753_mondo:0005550',
#  'ncbitaxon:289767_mondo:0005550',
#  'ncbitaxon:289799_mondo:0005550',
#  'ncbitaxon:290988_mondo:0005550',
#  'ncbitaxon:292239_mondo:0005550',
#  'ncbitaxon:292353_mondo:0005550',
#  'ncbitaxon:293060_mondo:0005550',
#  'ncbitaxon:29590_mondo:0005550',
#  'ncbitaxon:296035_mondo:0005550',
#  'ncbitaxon:296036_mondo:0005550',
#  'ncbitaxon:296037_mondo:0005550',
#  'ncbitaxon:29606_mondo:0005550',
#  'ncbitaxon:296875_mondo:0005550',
#  'ncbitaxon:29695_mondo:0005550',
#  'ncbitaxon:29722_mondo:0005550',
#  'ncbitaxon:29729_mondo:0005550',
#  'ncbitaxon:29760_mondo:0005550',
#  'ncbitaxon:29780_mondo:0005550',
#  'ncbitaxon:29818_mondo:0005550',
#  'ncbitaxon:298346_mondo:0005550',
#  'ncbitaxon:301481_mondo:0005550',
#  'ncbitaxon:301693_mondo:0005550',
#  'ncbitaxon:301862_mondo:0005550',
#  'ncbitaxon:304188_mondo:0005550',
#  'ncbitaxon:308223_mondo:0005550',
#  'ncbitaxon:309271_mondo:0005550',
#  'ncbitaxon:311405_mondo:0005550',
#  'ncbitaxon:313920_mondo:0005550',
#  'ncbitaxon:313931_mondo:0005550',
#  'ncbitaxon:316645_mondo:0005550',
#  'ncbitaxon:316758_mondo:0005550',
#  'ncbitaxon:317192_mondo:0005550',
#  'ncbitaxon:317856_mondo:0005550',
#  'ncbitaxon:318060_mondo:0005550',
#  'ncbitaxon:318061_mondo:0005550',
#  'ncbitaxon:318062_mondo:0005550',
#  'ncbitaxon:318065_mondo:0005550',
#  'ncbitaxon:318066_mondo:0005550',
#  'ncbitaxon:318068_mondo:0005550',
#  'ncbitaxon:318982_mondo:0005550',
#  'ncbitaxon:320667_mondo:0005550',
#  'ncbitaxon:32101_mondo:0005550',
#  'ncbitaxon:321551_mondo:0005550',
#  'ncbitaxon:32239_mondo:0005550',
#  'ncbitaxon:32247_mondo:0005550',
#  'ncbitaxon:323674_mondo:0005550',
#  'ncbitaxon:324593_mondo:0005550',
#  'ncbitaxon:3252_mondo:0005550',
#  'ncbitaxon:3258_mondo:0005550',
#  'ncbitaxon:3289_mondo:0005550',
#  'ncbitaxon:329760_mondo:0005550',
#  'ncbitaxon:330163_mondo:0005550',
#  'ncbitaxon:3311_mondo:0005550',
#  'ncbitaxon:33125_mondo:0005550',
#  'ncbitaxon:3322_mondo:0005550',
#  'ncbitaxon:334483_mondo:0005550',
#  'ncbitaxon:334664_mondo:0005550',
#  'ncbitaxon:334689_mondo:0005550',
#  'ncbitaxon:334690_mondo:0005550',
#  'ncbitaxon:339146_mondo:0005550',
#  'ncbitaxon:339321_mondo:0005550',
#  'ncbitaxon:339493_mondo:0005550',
#  'ncbitaxon:340444_mondo:0005550',
#  'ncbitaxon:3406_mondo:0005550',
#  'ncbitaxon:3415_mondo:0005550',
#  'ncbitaxon:34173_mondo:0005550',
#  'ncbitaxon:34199_mondo:0005550',
#  'ncbitaxon:34256_mondo:0005550',
#  'ncbitaxon:342581_mondo:0005550',
#  'ncbitaxon:34270_mondo:0005550',
#  'ncbitaxon:34274_mondo:0005550',
#  'ncbitaxon:34296_mondo:0005550',
#  'ncbitaxon:34301_mondo:0005550',
#  'ncbitaxon:3435_mondo:0005550',
#  'ncbitaxon:345151_mondo:0005550',
#  'ncbitaxon:345802_mondo:0005550',
#  'ncbitaxon:345815_mondo:0005550',
#  'ncbitaxon:3469_mondo:0005550',
#  'ncbitaxon:346985_mondo:0005550',
#  'ncbitaxon:346999_mondo:0005550',
#  'ncbitaxon:3483_mondo:0005550',
#  'ncbitaxon:3486_mondo:0005550',
#  'ncbitaxon:3494_mondo:0005550',
#  'ncbitaxon:3501_mondo:0005550',
#  'ncbitaxon:3530_mondo:0005550',
#  'ncbitaxon:3533_mondo:0005550',
#  'ncbitaxon:3538_mondo:0005550',
#  'ncbitaxon:3544_mondo:0005550',
#  'ncbitaxon:354526_mondo:0005550',
#  'ncbitaxon:3559_mondo:0005550',
#  'ncbitaxon:35608_mondo:0005550',
#  'ncbitaxon:35625_mondo:0005550',
#  'ncbitaxon:356275_mondo:0005550',
#  'ncbitaxon:35716_mondo:0005550',
#  'ncbitaxon:3572_mondo:0005550',
#  'ncbitaxon:35874_mondo:0005550',
#  'ncbitaxon:35883_mondo:0005550',
#  'ncbitaxon:3589_mondo:0005550',
#  'ncbitaxon:35925_mondo:0005550',
#  'ncbitaxon:35936_mondo:0005550',
#  'ncbitaxon:35974_mondo:0005550',
#  'ncbitaxon:360584_mondo:0005550',
#  'ncbitaxon:360610_mondo:0005550',
#  'ncbitaxon:361442_mondo:0005550',
#  'ncbitaxon:3631_mondo:0005550',
#  'ncbitaxon:3638_mondo:0005550',
#  'ncbitaxon:3641_mondo:0005550',
#  'ncbitaxon:3649_mondo:0005550',
#  'ncbitaxon:3654_mondo:0005550',
#  'ncbitaxon:3656_mondo:0005550',
#  'ncbitaxon:3659_mondo:0005550',
#  'ncbitaxon:3661_mondo:0005550',
#  'ncbitaxon:36610_mondo:0005550',
#  'ncbitaxon:3662_mondo:0005550',
#  'ncbitaxon:3673_mondo:0005550',
#  'ncbitaxon:36777_mondo:0005550',
#  'ncbitaxon:3704_mondo:0005550',
#  'ncbitaxon:371028_mondo:0005550',
#  'ncbitaxon:3712_mondo:0005550',
#  'ncbitaxon:371650_mondo:0005550',
#  'ncbitaxon:3719_mondo:0005550',
#  'ncbitaxon:3726_mondo:0005550',
#  'ncbitaxon:3730_mondo:0005550',
#  'ncbitaxon:373122_mondo:0005550',
#  'ncbitaxon:37334_mondo:0005550',
#  'ncbitaxon:3735_mondo:0005550',
#  'ncbitaxon:374122_mondo:0005550',
#  'ncbitaxon:37495_mondo:0005550',
#  'ncbitaxon:37565_mondo:0005550',
#  'ncbitaxon:3760_mondo:0005550',
#  'ncbitaxon:3765_mondo:0005550',
#  'ncbitaxon:37656_mondo:0005550',
#  'ncbitaxon:378224_mondo:0005550',
#  'ncbitaxon:379949_mondo:0005550',
#  'ncbitaxon:3806_mondo:0005550',
#  'ncbitaxon:3816_mondo:0005550',
#  'ncbitaxon:382341_mondo:0005550',
#  'ncbitaxon:3825_mondo:0005550',
#  'ncbitaxon:3827_mondo:0005550',
#  'ncbitaxon:3829_mondo:0005550',
#  'ncbitaxon:384659_mondo:0005550',
#  'ncbitaxon:3847_mondo:0005550',
#  'ncbitaxon:385002_mondo:0005550',
#  'ncbitaxon:3871_mondo:0005550',
#  'ncbitaxon:387127_mondo:0005550',
#  'ncbitaxon:3884_mondo:0005550',
#  'ncbitaxon:388479_mondo:0005550',
#  'ncbitaxon:3885_mondo:0005550',
#  'ncbitaxon:38859_mondo:0005550',
#  'ncbitaxon:38868_mondo:0005550',
#  'ncbitaxon:38869_mondo:0005550',
#  'ncbitaxon:38873_mondo:0005550',
#  'ncbitaxon:3893_mondo:0005550',
#  'ncbitaxon:38942_mondo:0005550',
#  'ncbitaxon:3906_mondo:0005550',
#  'ncbitaxon:3908_mondo:0005550',
#  'ncbitaxon:3917_mondo:0005550',
#  'ncbitaxon:3918_mondo:0005550',
#  'ncbitaxon:39338_mondo:0005550',
#  'ncbitaxon:39347_mondo:0005550',
#  'ncbitaxon:39350_mondo:0005550',
#  'ncbitaxon:39352_mondo:0005550',
#  'ncbitaxon:39358_mondo:0005550',
#  'ncbitaxon:39367_mondo:0005550',
#  'ncbitaxon:39387_mondo:0005550',
#  'ncbitaxon:39388_mondo:0005550',
#  'ncbitaxon:39414_mondo:0005550',
#  'ncbitaxon:39417_mondo:0005550',
#  'ncbitaxon:39470_mondo:0005550',
#  'ncbitaxon:39510_mondo:0005550',
#  'ncbitaxon:39534_mondo:0005550',
#  'ncbitaxon:396369_mondo:0005550',
#  'ncbitaxon:397098_mondo:0005550',
#  'ncbitaxon:3972_mondo:0005550',
#  'ncbitaxon:397370_mondo:0005550',
#  'ncbitaxon:3988_mondo:0005550',
#  'ncbitaxon:3996_mondo:0005550',
#  'ncbitaxon:39984_mondo:0005550',
#  'ncbitaxon:39993_mondo:0005550',
#  'ncbitaxon:4006_mondo:0005550',
#  'ncbitaxon:4020_mondo:0005550',
#  'ncbitaxon:4039_mondo:0005550',
#  'ncbitaxon:4043_mondo:0005550',
#  'ncbitaxon:4045_mondo:0005550',
#  'ncbitaxon:404689_mondo:0005550',
#  'ncbitaxon:404691_mondo:0005550',
#  'ncbitaxon:4047_mondo:0005550',
#  'ncbitaxon:4052_mondo:0005550',
#  'ncbitaxon:405322_mondo:0005550',
#  'ncbitaxon:4054_mondo:0005550',
#  'ncbitaxon:4058_mondo:0005550',
#  'ncbitaxon:4060_mondo:0005550',
#  'ncbitaxon:4066_mondo:0005550',
#  'ncbitaxon:4068_mondo:0005550',
#  'ncbitaxon:4072_mondo:0005550',
#  'ncbitaxon:4073_mondo:0005550',
#  'ncbitaxon:4079_mondo:0005550',
#  'ncbitaxon:4081_mondo:0005550',
#  'ncbitaxon:40922_mondo:0005550',
#  'ncbitaxon:4093_mondo:0005550',
#  'ncbitaxon:4097_mondo:0005550',
#  'ncbitaxon:4111_mondo:0005550',
#  'ncbitaxon:4112_mondo:0005550',
#  'ncbitaxon:4113_mondo:0005550',
#  'ncbitaxon:41220_mondo:0005550',
#  'ncbitaxon:41230_mondo:0005550',
#  'ncbitaxon:413272_mondo:0005550',
#  'ncbitaxon:413755_mondo:0005550',
#  'ncbitaxon:413762_mondo:0005550',
#  'ncbitaxon:41396_mondo:0005550',
#  'ncbitaxon:41398_mondo:0005550',
#  'ncbitaxon:41511_mondo:0005550',
#  'ncbitaxon:415160_mondo:0005550',
#  'ncbitaxon:41644_mondo:0005550',
#  'ncbitaxon:4182_mondo:0005550',
#  'ncbitaxon:4189_mondo:0005550',
#  'ncbitaxon:4202_mondo:0005550',
#  'ncbitaxon:421226_mondo:0005550',
#  'ncbitaxon:4217_mondo:0005550',
#  'ncbitaxon:4220_mondo:0005550',
#  'ncbitaxon:4222_mondo:0005550',
#  'ncbitaxon:4227_mondo:0005550',
#  'ncbitaxon:4232_mondo:0005550',
#  'ncbitaxon:42337_mondo:0005550',
#  'ncbitaxon:425843_mondo:0005550',
#  'ncbitaxon:429560_mondo:0005550',
#  'ncbitaxon:4298_mondo:0005550',
#  'ncbitaxon:430754_mondo:0005550',
#  'ncbitaxon:43335_mondo:0005550',
#  'ncbitaxon:43364_mondo:0005550',
#  'ncbitaxon:43366_mondo:0005550',
#  'ncbitaxon:4337_mondo:0005550',
#  'ncbitaxon:434235_mondo:0005550',
#  'ncbitaxon:434238_mondo:0005550',
#  'ncbitaxon:43503_mondo:0005550',
#  'ncbitaxon:43522_mondo:0005550',
#  'ncbitaxon:436207_mondo:0005550',
#  'ncbitaxon:4369_mondo:0005550',
#  'ncbitaxon:43851_mondo:0005550',
#  'ncbitaxon:43879_mondo:0005550',
#  'ncbitaxon:439689_mondo:0005550',
#  'ncbitaxon:441183_mondo:0005550',
#  'ncbitaxon:4419_mondo:0005550',
#  'ncbitaxon:4424_mondo:0005550',
#  'ncbitaxon:4432_mondo:0005550',
#  'ncbitaxon:4442_mondo:0005550',
#  'ncbitaxon:4460_mondo:0005550',
#  'ncbitaxon:4465_mondo:0005550',
#  'ncbitaxon:4477_mondo:0005550',
#  'ncbitaxon:449196_mondo:0005550',
#  'ncbitaxon:44947_mondo:0005550',
#  'ncbitaxon:4498_mondo:0005550',
#  'ncbitaxon:4505_mondo:0005550',
#  'ncbitaxon:4513_mondo:0005550',
#  'ncbitaxon:45164_mondo:0005550',
#  'ncbitaxon:45184_mondo:0005550',
#  'ncbitaxon:452763_mondo:0005550',
#  'ncbitaxon:452790_mondo:0005550',
#  'ncbitaxon:4530_mondo:0005550',
#  'ncbitaxon:45325_mondo:0005550',
#  'ncbitaxon:4540_mondo:0005550',
#  'ncbitaxon:4543_mondo:0005550',
#  'ncbitaxon:4547_mondo:0005550',
#  'ncbitaxon:454930_mondo:0005550',
#  'ncbitaxon:455045_mondo:0005550',
#  'ncbitaxon:4555_mondo:0005550',
#  'ncbitaxon:4558_mondo:0005550',
#  'ncbitaxon:4565_mondo:0005550',
#  'ncbitaxon:45683_mondo:0005550',
#  'ncbitaxon:457265_mondo:0005550',
#  'ncbitaxon:4577_mondo:0005550',
#  'ncbitaxon:457826_mondo:0005550',
#  'ncbitaxon:45834_mondo:0005550',
#  'ncbitaxon:459110_mondo:0005550',
#  'ncbitaxon:459147_mondo:0005550',
#  'ncbitaxon:459165_mondo:0005550',
#  'ncbitaxon:459629_mondo:0005550',
#  'ncbitaxon:460607_mondo:0005550',
#  'ncbitaxon:46142_mondo:0005550',
#  'ncbitaxon:4615_mondo:0005550',
#  'ncbitaxon:461633_mondo:0005550',
#  'ncbitaxon:467335_mondo:0005550',
#  'ncbitaxon:467606_mondo:0005550',
#  'ncbitaxon:4679_mondo:0005550',
#  'ncbitaxon:4681_mondo:0005550',
#  'ncbitaxon:4682_mondo:0005550',
#  'ncbitaxon:4683_mondo:0005550',
#  'ncbitaxon:468510_mondo:0005550',
#  'ncbitaxon:46901_mondo:0005550',
#  'ncbitaxon:470706_mondo:0005550',
#  'ncbitaxon:47083_mondo:0005550',
#  'ncbitaxon:471946_mondo:0005550',
#  'ncbitaxon:4744_mondo:0005550',
#  'ncbitaxon:475907_mondo:0005550',
#  'ncbitaxon:47619_mondo:0005550',
#  'ncbitaxon:478095_mondo:0005550',
#  'ncbitaxon:48032_mondo:0005550',
#  'ncbitaxon:48038_mondo:0005550',
#  'ncbitaxon:48106_mondo:0005550',
#  'ncbitaxon:483143_mondo:0005550',
#  'ncbitaxon:483232_mondo:0005550',
#  'ncbitaxon:483693_mondo:0005550',
#  'ncbitaxon:483799_mondo:0005550',
#  'ncbitaxon:483811_mondo:0005550',
#  'ncbitaxon:48386_mondo:0005550',
#  'ncbitaxon:485725_mondo:0005550',
#  'ncbitaxon:486425_mondo:0005550',
#  'ncbitaxon:487788_mondo:0005550',
#  'ncbitaxon:488982_mondo:0005550',
#  'ncbitaxon:492004_mondo:0005550',
#  'ncbitaxon:49314_mondo:0005550',
#  'ncbitaxon:493992_mondo:0005550',
#  'ncbitaxon:49511_mondo:0005550',
#  'ncbitaxon:49556_mondo:0005550',
#  'ncbitaxon:49577_mondo:0005550',
#  'ncbitaxon:49657_mondo:0005550',
#  'ncbitaxon:49666_mondo:0005550',
#  'ncbitaxon:497687_mondo:0005550',
#  'ncbitaxon:49827_mondo:0005550',
#  'ncbitaxon:49987_mondo:0005550',
#  'ncbitaxon:49992_mondo:0005550',
#  'ncbitaxon:49994_mondo:0005550',
#  'ncbitaxon:50174_mondo:0005550',
#  'ncbitaxon:50225_mondo:0005550',
#  'ncbitaxon:50308_mondo:0005550',
#  'ncbitaxon:50543_mondo:0005550',
#  'ncbitaxon:50866_mondo:0005550',
#  'ncbitaxon:51089_mondo:0005550',
#  'ncbitaxon:51240_mondo:0005550',
#  'ncbitaxon:512623_mondo:0005550',
#  'ncbitaxon:516549_mondo:0005550',
#  'ncbitaxon:52462_mondo:0005550',
#  'ncbitaxon:52471_mondo:0005550',
#  'ncbitaxon:52570_mondo:0005550',
#  'ncbitaxon:526790_mondo:0005550',
#  'ncbitaxon:52818_mondo:0005550',
#  'ncbitaxon:52822_mondo:0005550',
#  'ncbitaxon:52823_mondo:0005550',
#  'ncbitaxon:53159_mondo:0005550',
#  'ncbitaxon:536986_mondo:0005550',
#  'ncbitaxon:536997_mondo:0005550',
#  'ncbitaxon:53719_mondo:0005550',
#  'ncbitaxon:537489_mondo:0005550',
#  'ncbitaxon:53846_mondo:0005550',
#  'ncbitaxon:53852_mondo:0005550',
#  'ncbitaxon:53906_mondo:0005550',
#  'ncbitaxon:53923_mondo:0005550',
#  'ncbitaxon:542672_mondo:0005550',
#  'ncbitaxon:543564_mondo:0005550',
#  'ncbitaxon:54466_mondo:0005550',
#  'ncbitaxon:547469_mondo:0005550',
#  'ncbitaxon:54796_mondo:0005550',
#  'ncbitaxon:54860_mondo:0005550',
#  'ncbitaxon:554542_mondo:0005550',
#  'ncbitaxon:55501_mondo:0005550',
#  'ncbitaxon:55513_mondo:0005550',
#  'ncbitaxon:555479_mondo:0005550',
#  'ncbitaxon:55598_mondo:0005550',
#  'ncbitaxon:556509_mondo:0005550',
#  'ncbitaxon:55843_mondo:0005550',
#  'ncbitaxon:56060_mondo:0005550',
#  'ncbitaxon:56065_mondo:0005550',
#  'ncbitaxon:56866_mondo:0005550',
#  'ncbitaxon:571269_mondo:0005550',
#  'ncbitaxon:578558_mondo:0005550',
#  'ncbitaxon:57919_mondo:0005550',
#  'ncbitaxon:58039_mondo:0005550',
#  'ncbitaxon:58046_mondo:0005550',
#  'ncbitaxon:58048_mondo:0005550',
#  'ncbitaxon:581247_mondo:0005550',
#  'ncbitaxon:58228_mondo:0005550',
#  'ncbitaxon:58502_mondo:0005550',
#  'ncbitaxon:587868_mondo:0005550',
#  'ncbitaxon:588205_mondo:0005550',
#  'ncbitaxon:58860_mondo:0005550',
#  'ncbitaxon:58944_mondo:0005550',
#  'ncbitaxon:591145_mondo:0005550',
#  'ncbitaxon:59116_mondo:0005550',
#  'ncbitaxon:59170_mondo:0005550',
#  'ncbitaxon:591754_mondo:0005550',
#  'ncbitaxon:592576_mondo:0005550',
#  'ncbitaxon:59292_mondo:0005550',
#  'ncbitaxon:59492_mondo:0005550',
#  'ncbitaxon:59671_mondo:0005550',
#  'ncbitaxon:59982_mondo:0005550',
#  'ncbitaxon:60093_mondo:0005550',
#  'ncbitaxon:613112_mondo:0005550',
#  'ncbitaxon:61450_mondo:0005550',
#  'ncbitaxon:616984_mondo:0005550',
#  'ncbitaxon:62097_mondo:0005550',
#  'ncbitaxon:62123_mondo:0005550',
#  'ncbitaxon:622458_mondo:0005550',
#  'ncbitaxon:62335_mondo:0005550',
#  'ncbitaxon:63066_mondo:0005550',
#  'ncbitaxon:63359_mondo:0005550',
#  'ncbitaxon:63360_mondo:0005550',
#  'ncbitaxon:634377_mondo:0005550',
#  'ncbitaxon:63476_mondo:0005550',
#  'ncbitaxon:63479_mondo:0005550',
#  'ncbitaxon:63779_mondo:0005550',
#  'ncbitaxon:63789_mondo:0005550',
#  'ncbitaxon:64025_mondo:0005550',
#  'ncbitaxon:64032_mondo:0005550',
#  'ncbitaxon:640695_mondo:0005550',
#  'ncbitaxon:64109_mondo:0005550',
#  'ncbitaxon:645647_mondo:0005550',
#  'ncbitaxon:648879_mondo:0005550',
#  'ncbitaxon:653463_mondo:0005550',
#  'ncbitaxon:65409_mondo:0005550',
#  'ncbitaxon:654402_mondo:0005550',
#  'ncbitaxon:65558_mondo:0005550',
#  'ncbitaxon:65561_mondo:0005550',
#  'ncbitaxon:65948_mondo:0005550',
#  'ncbitaxon:66014_mondo:0005550',
#  'ncbitaxon:662901_mondo:0005550',
#  'ncbitaxon:66384_mondo:0005550',
#  'ncbitaxon:66387_mondo:0005550',
#  'ncbitaxon:66656_mondo:0005550',
#  'ncbitaxon:666687_mondo:0005550',
#  'ncbitaxon:66672_mondo:0005550',
#  'ncbitaxon:669130_mondo:0005550',
#  'ncbitaxon:670324_mondo:0005550',
#  'ncbitaxon:671526_mondo:0005550',
#  'ncbitaxon:67918_mondo:0005550',
#  'ncbitaxon:67938_mondo:0005550',
#  'ncbitaxon:680190_mondo:0005550',
#  'ncbitaxon:680227_mondo:0005550',
#  'ncbitaxon:680229_mondo:0005550',
#  'ncbitaxon:681286_mondo:0005550',
#  'ncbitaxon:681445_mondo:0005550',
#  'ncbitaxon:68527_mondo:0005550',
#  'ncbitaxon:69109_mondo:0005550',
#  'ncbitaxon:69381_mondo:0005550',
#  'ncbitaxon:69717_mondo:0005550',
#  'ncbitaxon:70070_mondo:0005550',
#  'ncbitaxon:703614_mondo:0005550',
#  'ncbitaxon:714517_mondo:0005550',
#  'ncbitaxon:71610_mondo:0005550',
#  'ncbitaxon:71611_mondo:0005550',
#  'ncbitaxon:71650_mondo:0005550',
#  'ncbitaxon:71982_mondo:0005550',
#  'ncbitaxon:72341_mondo:0005550',
#  'ncbitaxon:72368_mondo:0005550',
#  'ncbitaxon:72402_mondo:0005550',
#  'ncbitaxon:72433_mondo:0005550',
#  'ncbitaxon:72917_mondo:0005550',
#  'ncbitaxon:73200_mondo:0005550',
#  'ncbitaxon:74613_mondo:0005550',
#  'ncbitaxon:74636_mondo:0005550',
#  'ncbitaxon:74649_mondo:0005550',
#  'ncbitaxon:74656_mondo:0005550',
#  'ncbitaxon:747363_mondo:0005550',
#  'ncbitaxon:75704_mondo:0005550',
#  'ncbitaxon:75706_mondo:0005550',
#  'ncbitaxon:75722_mondo:0005550',
#  'ncbitaxon:75943_mondo:0005550',
#  'ncbitaxon:75953_mondo:0005550',
#  'ncbitaxon:759864_mondo:0005550',
#  'ncbitaxon:76149_mondo:0005550',
#  'ncbitaxon:76306_mondo:0005550',
#  'ncbitaxon:76396_mondo:0005550',
#  'ncbitaxon:77880_mondo:0005550',
#  'ncbitaxon:78534_mondo:0005550',
#  'ncbitaxon:78774_mondo:0005550',
#  'ncbitaxon:79408_mondo:0005550',
#  'ncbitaxon:79559_mondo:0005550',
#  'ncbitaxon:79772_mondo:0005550',
#  'ncbitaxon:79835_mondo:0005550',
#  'ncbitaxon:79837_mondo:0005550',
#  'ncbitaxon:80913_mondo:0005550',
#  'ncbitaxon:81800_mondo:0005550',
#  'ncbitaxon:82528_mondo:0005550',
#  'ncbitaxon:82713_mondo:0005550',
#  'ncbitaxon:83154_mondo:0005550',
#  'ncbitaxon:83951_mondo:0005550',
#  'ncbitaxon:85223_mondo:0005550',
#  'ncbitaxon:85232_mondo:0005550',
#  'ncbitaxon:85330_mondo:0005550',
#  'ncbitaxon:85358_mondo:0005550',
#  'ncbitaxon:85571_mondo:0005550',
#  'ncbitaxon:857679_mondo:0005550',
#  'ncbitaxon:85835_mondo:0005550',
#  'ncbitaxon:859317_mondo:0005550',
#  'ncbitaxon:85961_mondo:0005550',
#  'ncbitaxon:86757_mondo:0005550',
#  'ncbitaxon:87086_mondo:0005550',
#  'ncbitaxon:886265_mondo:0005550',
#  'ncbitaxon:890036_mondo:0005550',
#  'ncbitaxon:89151_mondo:0005550',
#  'ncbitaxon:89411_mondo:0005550',
#  'ncbitaxon:89634_mondo:0005550',
#  'ncbitaxon:89636_mondo:0005550',
#  'ncbitaxon:90528_mondo:0005550',
#  'ncbitaxon:909143_mondo:0005550',
#  'ncbitaxon:925357_mondo:0005550',
#  'ncbitaxon:930814_mondo:0005550',
#  'ncbitaxon:930817_mondo:0005550',
#  'ncbitaxon:93608_mondo:0005550',
#  'ncbitaxon:93692_mondo:0005550',
#  'ncbitaxon:93759_mondo:0005550',
#  'ncbitaxon:93772_mondo:0005550',
#  'ncbitaxon:93784_mondo:0005550',
#  'ncbitaxon:93794_mondo:0005550',
#  'ncbitaxon:94328_mondo:0005550',
#  'ncbitaxon:948718_mondo:0005550',
#  'ncbitaxon:97441_mondo:0005550',
#  'ncbitaxon:97754_mondo:0005550',
#  'ncbitaxon:984867_mondo:0005550',
#  'ncbitaxon:992658_mondo:0005550',
#  'ncbitaxon:99294_mondo:0005550',
#  'ncbitaxon:994668_mondo:0005550',
#  'ncbitaxon:100514_mondo:0005550',
#  'ncbitaxon:100521_mondo:0005550',
#  'ncbitaxon:101743_mondo:0005550',
#  'ncbitaxon:108594_mondo:0005550',
#  'ncbitaxon:112883_mondo:0005550',
#  'ncbitaxon:1210469_mondo:0005550',
#  'ncbitaxon:126903_mondo:0005550',
#  'ncbitaxon:1353443_mondo:0005550',
#  'ncbitaxon:14027_mondo:0005550',
#  'ncbitaxon:146466_mondo:0005550',
#  'ncbitaxon:1518212_mondo:0005550',
#  'ncbitaxon:152355_mondo:0005550',
#  'ncbitaxon:152374_mondo:0005550',
#  'ncbitaxon:167572_mondo:0005550',
#  'ncbitaxon:169210_mondo:0005550',
#  'ncbitaxon:176265_mondo:0005550',
#  'ncbitaxon:255872_mondo:0005550',
#  'ncbitaxon:2580341_mondo:0005550',
#  'ncbitaxon:29808_mondo:0005550',
#  'ncbitaxon:3197_mondo:0005550',
#  'ncbitaxon:323663_mondo:0005550',
#  'ncbitaxon:33128_mondo:0005550',
#  'ncbitaxon:352190_mondo:0005550',
#  'ncbitaxon:3897_mondo:0005550',
#  'ncbitaxon:439925_mondo:0005550',
#  'ncbitaxon:443222_mondo:0005550',
#  'ncbitaxon:4443_mondo:0005550',
#  'ncbitaxon:44681_mondo:0005550',
#  'ncbitaxon:449854_mondo:0005550',
#  'ncbitaxon:453243_mondo:0005550',
#  'ncbitaxon:49684_mondo:0005550',
#  'ncbitaxon:54804_mondo:0005550',
#  'ncbitaxon:56033_mondo:0005550',
#  'ncbitaxon:627158_mondo:0005550',
#  'ncbitaxon:68554_mondo:0005550',
#  'ncbitaxon:714442_mondo:0005550',
#  'ncbitaxon:71608_mondo:0005550',
#  'ncbitaxon:76025_mondo:0005550',
#  'ncbitaxon:78457_mondo:0005550',
#  'ncbitaxon:83819_mondo:0005550',
#  'ncbitaxon:88036_mondo:0005550',
#  'ncbitaxon:88730_mondo:0005550',
#  'ncbitaxon:90693_mondo:0005550',
#  'ncbitaxon:99300_mondo:0005550',
#  'ncbitaxon:1079077_mondo:0005550',
#  'ncbitaxon:1125377_mondo:0005550',
#  'ncbitaxon:1224788_mondo:0005550',
#  'ncbitaxon:1234621_mondo:0005550',
#  'ncbitaxon:1268258_mondo:0005550',
#  'ncbitaxon:138060_mondo:0005550',
#  'ncbitaxon:1421005_mondo:0005550',
#  'ncbitaxon:1453846_mondo:0005550',
#  'ncbitaxon:1471003_mondo:0005550',
#  'ncbitaxon:148671_mondo:0005550',
#  'ncbitaxon:148672_mondo:0005550',
#  'ncbitaxon:149628_mondo:0005550',
#  'ncbitaxon:149685_mondo:0005550',
#  'ncbitaxon:1532509_mondo:0005550',
#  'ncbitaxon:1544812_mondo:0005550',
#  'ncbitaxon:1645775_mondo:0005550',
#  'ncbitaxon:176562_mondo:0005550',
#  'ncbitaxon:1874268_mondo:0005550',
#  'ncbitaxon:1902340_mondo:0005550',
#  'ncbitaxon:191889_mondo:0005550',
#  'ncbitaxon:192415_mondo:0005550',
#  'ncbitaxon:1954548_mondo:0005550',
#  'ncbitaxon:1954554_mondo:0005550',
#  'ncbitaxon:1954593_mondo:0005550',
#  'ncbitaxon:20676_mondo:0005550',
#  'ncbitaxon:2072218_mondo:0005550',
#  'ncbitaxon:225969_mondo:0005550',
#  'ncbitaxon:264955_mondo:0005550',
#  'ncbitaxon:280048_mondo:0005550',
#  'ncbitaxon:327143_mondo:0005550',
#  'ncbitaxon:327905_mondo:0005550',
#  'ncbitaxon:327906_mondo:0005550',
#  'ncbitaxon:327908_mondo:0005550',
#  'ncbitaxon:3334_mondo:0005550',
#  'ncbitaxon:3837_mondo:0005550',
#  'ncbitaxon:397171_mondo:0005550',
#  'ncbitaxon:397180_mondo:0005550',
#  'ncbitaxon:397630_mondo:0005550',
#  'ncbitaxon:397653_mondo:0005550',
#  'ncbitaxon:413686_mondo:0005550',
#  ...]

# %%
# Fitering out edges without citation count greater than 3

plant_disease_dict = {
    i: j
    for i, j in plant_disease_dict.items()
    if j > 5
}
len(plant_disease_dict)
# Out:
# 817

# %%
all_plants = set(
    i.split('_')[0]
    for i, _ in plant_disease_dict.items()
)
len(all_plants)
# Out:
# 163

# %% [raw]
# ### Counts for each disease
# for i in disease_areas_of_interest:
#     plant_count = plant_disease_data[
#         plant_disease_data['disease_curie'] == i
#     ]['plant_curie'].unique().tolist()
#     print(i, len(plant_count))

# %%
disease_areas_of_interest = [
    "mondo:0037940",  # auditory system disorder
    "mondo:0002657",  # breast disorder
    "mondo:0004992",  # cancer or benign tumor
    "mondo:0004995",  # cardiovascular disorder
    "mondo:0003900",  # connective tissue disorder
    "mondo:0004335",  # digestive system disorder
    "mondo:0021084",  # disorder of visual system
    "mondo:0005151",  # endocrine system disorder
    "mondo:0005570",  # hematologic disorder
    "mondo:0005046",  # immune system disorder
    "mondo:0021166",  # inflammatory disease
    "mondo:0021178",  # injury
    "mondo:0002051",  # integumentary system disorder
    "mondo:0005550",  # infectious disease or post-infectious disorder
    "mondo:0005066",  # metabolic disease
    "mondo:0002081",  # musculoskeletal system disorder
    "mondo:0005071",  # nervous system disorder
    "mondo:0005137",  # nutritional disorder
    "mondo:0024623",  # otorhinolaryngologic disease
    "mondo:0029000",  # poisoning
    "mondo:0002025",  # psychiatric disorder
    "mondo:0005087",  # respiratory system disorder
    "mondo:0002118",  # urinary system disorder
]

# %% [markdown]
# ### Selection inflamtory diseases

# %%
disease_plant_list = plant_data[
    plant_data['disease_curie'] == 'mondo:0005137'
]['plant_curie'].unique().tolist()
len(disease_plant_list)
# Out:
# 166

# %% [raw]
# all_plants = plant_disease_data[
#     plant_disease_data['disease_curie'].isin(['mondo:0005046', 'mondo:0021166'])
# ]['plant_curie'].unique().tolist()
# len(all_plants)

# %% [raw]
# plant_naming_dict = defaultdict(str)
#
# for plant_curie, plant_name in tqdm(plant_disease_data[['plant_curie', 'plant_name']].values):
#     if pd.isna(plant_name):
#         continue
#
#     if plant_curie in plant_naming_dict:
#         continue
#
#     plant_naming_dict[plant_curie] = plant_name
#
# len(plant_naming_dict)

# %% [markdown]
# ### Get lineage of each plant from NCBITaxon

# %%
ncbi = NCBITaxa()

# %% [markdown]
# ### Generate Newick tree format

# %%
def newickify(node_to_children, root_node) -> str:
    visited_nodes = set()

    def newick_render_node(name, distance: float) -> str:
        if isinstance(name, str):
            name = name.replace(' ', '_')
        assert name not in visited_nodes, "Error: The tree may not be circular!"

        if name not in node_to_children:
            # Leafs
            return F'{name}:{distance}'
        else:
            # Nodes
            visited_nodes.add(name)
            children = node_to_children[name]
            children_strings = [newick_render_node(child, children[child]) for child in children.keys()]
            children_strings = ",".join(children_strings)
            return F'({children_strings}){name}:{distance}'

    newick_string = newick_render_node(root_node, 0) + ';'

    # Ensure no entries in the dictionary are left unused.
    assert visited_nodes == set(node_to_children.keys()), "Error: some nodes aren't in the tree"

    return newick_string

# %% [raw]
# lineage_dict = defaultdict(dict)
#
# for plant in tqdm(plant_naming_dict.keys()):
#     tree = ncbi.get_lineage(plant.split(':')[1])
#     for idx in range(len(tree) - 1):
#         if str(tree[idx]) in plant_naming_dict:
#             parent = plant_naming_dict[str(tree[idx])]
#         else:
#             parent = tree[idx]
#
#         if str(tree[idx + 1]) in plant_naming_dict:
#             child = plant_naming_dict[str(tree[idx + 1])]
#         else:
#             child = tree[idx + 1]
#
#         # Hard coded due to obselet terms in ontology (to avoid error messages)
#
# #         if str(tree[idx]) == '2849586':
# #             parent = plant_naming_dict['48038']
#
# #         if str(tree[idx + 1]) == '2849586':
# #             child = plant_naming_dict['48038']
#
#         lineage_dict[parent][child] = idx + 1

# %%
lineage_dict = defaultdict(dict)

for plant in tqdm(all_plants):
    tree = ncbi.get_lineage(plant.split(':')[1])
    for idx in range(len(tree) - 1):
        
        parent = tree[idx]
        
        child = tree[idx + 1]
                     
        lineage_dict[parent][child] = idx + 1
# Out:
#   0%|                                                                                                                                               | 0/163 [00:00<?, ?it/s]/Users/yojana/anaconda3/envs/kg-sources/lib/python3.9/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 48038 was translated into 2849586
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /Users/yojana/anaconda3/envs/kg-sources/lib/python3.9/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 32224 was translated into 2843217
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 163/163 [00:00<00:00, 4102.39it/s]

# %%
string = newickify(lineage_dict, root_node=1)

# %%
biophylo_tree = Phylo.read(StringIO(string), "newick")

# %% [markdown]
# ### Visualizing tree

# %%
fig = figure(figsize=(10, 10), dpi=300)
fig.subplots_adjust(hspace = .5)


for clade in biophylo_tree.get_terminals() :
    clade.patch = lambda coordinates : Circle(coordinates, 0.01, color="black")

# heatmap data

labels = []
tp = []

hdata = {}
c = 0
for leaf in biophylo_tree.get_terminals():
    hdata.setdefault(leaf, {})
    
    # Get data from df
#     for i, j in plant_naming_dict.items():
#         if j == leaf.name.replace('_', ' '):
#             idx = i
#             break
            
    if f'ncbitaxon:{leaf}' in disease_plant_list:
        tp.append(f'ncbitaxon:{leaf}')
        labels.append(leaf.name)
        hdata[leaf]['Disease'] = 1
    else:
        hdata[leaf]['Disease'] = 0

# initialization and drawing
        
ax1 = fig.add_subplot(111, polar=True)

ep = Externals_patchs(bg_internal=True)
el = Externals_labels(size=2.8, bg_internal=True, offset=0.1, pad=0.1)
eh = Externals_heatmap(data=hdata, offset=0.5, size=4)
externals = [ep, el, eh]

ax1 = polar_plot(biophylo_tree, ax=ax1, pad_wedge=0, externals=externals,
    label_leaf=labels, patch_leaf=True, wedge=False)
# Out:
# /Users/yojana/Documents/GitHub/ethnobotany/notebooks/PhyloCircular/externals.py:196: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   wedge = Wedge((0, 0), depth, min_angle, max_angle, width=vertical_cell_size,
